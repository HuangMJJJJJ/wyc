# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base = np.load(r'output\experiment2\base_results.npy')
qky = np.load(r'output\experiment2\methon_qky_results.npy')
mine = np.load(r'output\experiment2\mine_results_1.npy')

# %%
cls = ["base"] * base.shape[0] + ["qky"] * qky.shape[0] + ["mine"] * mine.shape[0]
df = pd.DataFrame(
    np.concatenate([base, qky, mine]),
    columns=["train size", "accuracy score", "f1 score"],
)
df["cls"] = cls
df
# Out:
#        train size  accuracy score  f1 score   cls
# 0             3.0        0.829932  0.821470  base
# 1             3.0        0.755102  0.754181  base
# 2             3.0        0.918367  0.917878  base
# 3             3.0        0.884354  0.882282  base
# 4             3.0        0.714286  0.675189  base
# ...           ...             ...       ...   ...
# 14695       147.0        1.000000  1.000000  mine
# 14696       147.0        1.000000  1.000000  mine
# 14697       147.0        1.000000  1.000000  mine
# 14698       147.0        1.000000  1.000000  mine
# 14699       147.0        1.000000  1.000000  mine
#
# [14700 rows x 4 columns]

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 6))
axs = axs.flatten()
ax = sns.lineplot(x="train size", y="accuracy score", hue="cls", data=df, ax=axs[0])
ax.set_ylim([0.8, 1.0])
ax = sns.lineplot(x="train size", y="f1 score", hue="cls", data=df, ax=axs[1])
ax.set_ylim([0.8, 1.0])
plt.show()
